# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('./kaggle/input/spaceship-titanic/train_update.csv')
df01 = pd.read_csv('./kaggle/input/spaceship-titanic/train.csv')

# %% [markdown]
# ### 이상치 확인
# 수치형 데이터만
# 1. Cabin_num
# 2. Age
# 3. RoomService
# 4. FoodCourt
# 5. ShoppingMall
# 6. Spa
# 7. VRDeck

# %%
df.columns
# Out:
# Index(['PassengerId', 'HomePlanet', 'CryoSleep', 'Cabin', 'Cabin_num',
#        'Cabin_port', 'Destination', 'Age', 'VIP', 'RoomService', 'FoodCourt',
#        'ShoppingMall', 'Spa', 'VRDeck', 'Name', 'Transported'],
#       dtype='object')

# %%
df.groupby('Age').count()
# Out:
#      PassengerId  HomePlanet  CryoSleep  Cabin  Cabin_num  Cabin_port  \
# Age
# 0            178         178        178    178        178         178
# 1             67          67         67     67         67          67
# 2             75          75         75     75         75          75
# 3             75          75         75     75         75          75
# 4             71          71         71     71         71          71
# ..           ...         ...        ...    ...        ...         ...
# 75             4           4          4      4          4           4
# 76             2           2          2      2          2           2
# 77             2           2          2      2          2           2
# 78             3           3          3      3          3           3
# 79             3           3          3      3          3           3
#
#      Destination  VIP  RoomService  FoodCourt  ShoppingMall  Spa  VRDeck  \
# Age
# ...

# %%
# 1. Cabin_num
import matplotlib.pyplot as plt

plt.figure(figsize=(6,10))
boxplot = df.boxplot(column=['Cabin_num'])
plt.yticks(np.arange(0,2000,step=100))
plt.show()

# %%
# 2. Age
import matplotlib.pyplot as plt

plt.figure(figsize=(6,10))
boxplot = df.boxplot(column=['Age'])
plt.yticks(np.arange(0,100,step=5))
plt.show()

# %%
# 3. AgRoomServicee
import matplotlib.pyplot as plt

plt.figure(figsize=(6,20))
boxplot = df.boxplot(column=['RoomService'])
plt.yticks(np.arange(0,15000,step=1000))
plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x1cdfcbe7ac0>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 1000, '1000'),
#   Text(0, 2000, '2000'),
#   Text(0, 3000, '3000'),
#   Text(0, 4000, '4000'),
#   Text(0, 5000, '5000'),
#   Text(0, 6000, '6000'),
#   Text(0, 7000, '7000'),
#   Text(0, 8000, '8000'),
#   Text(0, 9000, '9000'),
#   Text(0, 10000, '10000'),
#   Text(0, 11000, '11000'),
#   Text(0, 12000, '12000'),
#   Text(0, 13000, '13000'),
#   Text(0, 14000, '14000')])

# %%
# 4. FoodCourt
import matplotlib.pyplot as plt

plt.figure(figsize=(6,20))
boxplot = df.boxplot(column=['FoodCourt'])
plt.yticks(np.arange(0,30000,step=1000))
plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x1cdfdf027a0>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 1000, '1000'),
#   Text(0, 2000, '2000'),
#   Text(0, 3000, '3000'),
#   Text(0, 4000, '4000'),
#   Text(0, 5000, '5000'),
#   Text(0, 6000, '6000'),
#   Text(0, 7000, '7000'),
#   Text(0, 8000, '8000'),
#   Text(0, 9000, '9000'),
#   Text(0, 10000, '10000'),
#   Text(0, 11000, '11000'),
#   Text(0, 12000, '12000'),
#   Text(0, 13000, '13000'),
#   Text(0, 14000, '14000'),
#   Text(0, 15000, '15000'),
#   Text(0, 16000, '16000'),
#   Text(0, 17000, '17000'),
#   Text(0, 18000, '18000'),
#   Text(0, 19000, '19000'),
#   Text(0, 20000, '20000'),
#   Text(0, 21000, '21000'),
#   Text(0, 22000, '22000'),
#   Text(0, 23000, '23000'),
#   Text(0, 24000, '24000'),
#   Text(0, 25000, '25000'),
#   Text(0, 26000, '26000'),
#   Text(0, 27000, '27000'),
#   Text(0, 28000, '28000'),
#   Text(0, 29000, '29000')])

# %%
# 5. ShoppingMall
import matplotlib.pyplot as plt

plt.figure(figsize=(6,20))
boxplot = df.boxplot(column=['ShoppingMall'])
plt.yticks(np.arange(0,30000,step=1000))
plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x1cdfa6479d0>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 1000, '1000'),
#   Text(0, 2000, '2000'),
#   Text(0, 3000, '3000'),
#   Text(0, 4000, '4000'),
#   Text(0, 5000, '5000'),
#   Text(0, 6000, '6000'),
#   Text(0, 7000, '7000'),
#   Text(0, 8000, '8000'),
#   Text(0, 9000, '9000'),
#   Text(0, 10000, '10000'),
#   Text(0, 11000, '11000'),
#   Text(0, 12000, '12000'),
#   Text(0, 13000, '13000'),
#   Text(0, 14000, '14000'),
#   Text(0, 15000, '15000'),
#   Text(0, 16000, '16000'),
#   Text(0, 17000, '17000'),
#   Text(0, 18000, '18000'),
#   Text(0, 19000, '19000'),
#   Text(0, 20000, '20000'),
#   Text(0, 21000, '21000'),
#   Text(0, 22000, '22000'),
#   Text(0, 23000, '23000'),
#   Text(0, 24000, '24000'),
#   Text(0, 25000, '25000'),
#   Text(0, 26000, '26000'),
#   Text(0, 27000, '27000'),
#   Text(0, 28000, '28000'),
#   Text(0, 29000, '29000')])

# %%
# 6. Spa
import matplotlib.pyplot as plt

plt.figure(figsize=(6,20))
boxplot = df.boxplot(column=['Spa'])
plt.yticks(np.arange(0,24000,step=1000))
plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x1cdfde0ddb0>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 1000, '1000'),
#   Text(0, 2000, '2000'),
#   Text(0, 3000, '3000'),
#   Text(0, 4000, '4000'),
#   Text(0, 5000, '5000'),
#   Text(0, 6000, '6000'),
#   Text(0, 7000, '7000'),
#   Text(0, 8000, '8000'),
#   Text(0, 9000, '9000'),
#   Text(0, 10000, '10000'),
#   Text(0, 11000, '11000'),
#   Text(0, 12000, '12000'),
#   Text(0, 13000, '13000'),
#   Text(0, 14000, '14000'),
#   Text(0, 15000, '15000'),
#   Text(0, 16000, '16000'),
#   Text(0, 17000, '17000'),
#   Text(0, 18000, '18000'),
#   Text(0, 19000, '19000'),
#   Text(0, 20000, '20000'),
#   Text(0, 21000, '21000'),
#   Text(0, 22000, '22000'),
#   Text(0, 23000, '23000')])

# %%
# 7. VRDeck
import matplotlib.pyplot as plt

plt.figure(figsize=(6,20))
boxplot = df.boxplot(column=['VRDeck'])
plt.yticks(np.arange(0,25000,step=1000))
plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x1cdfd83ba30>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 1000, '1000'),
#   Text(0, 2000, '2000'),
#   Text(0, 3000, '3000'),
#   Text(0, 4000, '4000'),
#   Text(0, 5000, '5000'),
#   Text(0, 6000, '6000'),
#   Text(0, 7000, '7000'),
#   Text(0, 8000, '8000'),
#   Text(0, 9000, '9000'),
#   Text(0, 10000, '10000'),
#   Text(0, 11000, '11000'),
#   Text(0, 12000, '12000'),
#   Text(0, 13000, '13000'),
#   Text(0, 14000, '14000'),
#   Text(0, 15000, '15000'),
#   Text(0, 16000, '16000'),
#   Text(0, 17000, '17000'),
#   Text(0, 18000, '18000'),
#   Text(0, 19000, '19000'),
#   Text(0, 20000, '20000'),
#   Text(0, 21000, '21000'),
#   Text(0, 22000, '22000'),
#   Text(0, 23000, '23000'),
#   Text(0, 24000, '24000')])

# %%
df.groupby('VRDeck').count()
# Out:
#         PassengerId  HomePlanet  CryoSleep  Cabin  Cabin_num  Cabin_port  \
# VRDeck
# 0              5497        5497       5497   5497       5497        5497
# 1               139         139        139    139        139         139
# 2                70          70         70     70         70          70
# 3                56          56         56     56         56          56
# 4                47          47         47     47         47          47
# ...             ...         ...        ...    ...        ...         ...
# 16337             1           1          1      1          1           1
# 17074             1           1          1      1          1           1
# 17306             1           1          1      1          1           1
# 20336             1           1          1      1          1           1
# 24133             1           1          1      1          1           1
#
#         Destination   Age   VIP  RoomService  FoodCourt  ShoppingMall   Spa  \
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'HomePlanet', 'CryoSleep', 'Cabin', 'Cabin_num',
#        'Cabin_port', 'Destination', 'Age', 'VIP', 'RoomService', 'FoodCourt',
#        'ShoppingMall', 'Spa', 'VRDeck', 'Name', 'Transported'],
#       dtype='object')
