# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('C:/ds_work/source_code/Project_DS/data/died_rate.csv')

# %%
df
# Out:
#       index  HomePlanet_entire  HomePlanet_died  HomePlanet_rate  index.1  \
# 0       0.0             4714.0           2719.0            57.68      0.0
# 1       1.0             2175.0            740.0            34.02      1.0
# 2       2.0             1804.0            856.0            47.45      NaN
# 3       NaN                NaN              NaN              NaN      NaN
# 4       NaN                NaN              NaN              NaN      NaN
# ...     ...                ...              ...              ...      ...
# 1360    NaN                NaN              NaN              NaN      NaN
# 1361    NaN                NaN              NaN              NaN      NaN
# 1362    NaN                NaN              NaN              NaN      NaN
# 1363    NaN                NaN              NaN              NaN      NaN
# 1364    NaN                NaN              NaN              NaN      NaN
#
#       CryoSleep_entire  CryoSleep_died  CryoSleep_rate  index.2  Cabin_entire  \
# 0               5568.0          3741.0           67.19      0.0         256.0
# 1               3125.0           574.0           18.37      1.0         779.0
# 2                  NaN             NaN             NaN      2.0         747.0
# 3                  NaN             NaN             NaN      3.0         495.0
# 4                  NaN             NaN             NaN      4.0        1025.0
# ...                ...             ...             ...      ...           ...
# 1360               NaN             NaN             NaN      NaN           NaN
# 1361               NaN             NaN             NaN      NaN           NaN
# 1362               NaN             NaN             NaN      NaN           NaN
# 1363               NaN             NaN             NaN      NaN           NaN
# 1364               NaN             NaN             NaN      NaN           NaN
#
#       ...  ShoppingMall_died  ShoppingMall_rate  index.11  Spa_entire  \
# 0     ...             2260.0              39.77       0.0      5324.0
# 1     ...              116.0              75.82       1.0       146.0
# 2     ...               61.0              76.25       2.0       105.0
# 3     ...               41.0              69.49       3.0        53.0
# 4     ...               36.0              80.00       4.0        46.0
# ...   ...                ...                ...       ...         ...
# 1360  ...                NaN                NaN       NaN         NaN
# 1361  ...                NaN                NaN       NaN         NaN
# 1362  ...                NaN                NaN       NaN         NaN
# 1363  ...                NaN                NaN       NaN         NaN
# 1364  ...                NaN                NaN       NaN         NaN
#
#       Spa_died  Spa_rate  index.12  VRDeck_entire  VRDeck_died  VRDeck_rate
# 0       1921.0     36.08       0.0         5497.0       2044.0        37.18
# 1         94.0     64.38       1.0          139.0         92.0        66.19
# 2         58.0     55.24       2.0           70.0         41.0        58.57
# 3         29.0     54.72       3.0           56.0         39.0        69.64
# 4         29.0     63.04       4.0           47.0         28.0        59.57
# ...        ...       ...       ...            ...          ...          ...
# 1360       NaN       NaN       NaN            NaN          NaN          NaN
# 1361       NaN       NaN       NaN            NaN          NaN          NaN
# 1362       NaN       NaN       NaN            NaN          NaN          NaN
# 1363       NaN       NaN       NaN            NaN          NaN          NaN
# 1364       NaN       NaN       NaN            NaN          NaN          NaN
#
# [1365 rows x 52 columns]

# %%
#위의 형식을 적용
import matplotlib.pyplot as plt

#객체 픽셀 크기 지정
plt.figure(figsize=(10,6))

#폰트, 폰트 사이즈 지정
plt.rcParams["font.family"]='gulim'
plt.rcParams["font.size"]=12

#바 설정
plt.bar(df['index.1'], df['CryoSleep_entire'],  color='blue')

plt.title("CryoSleep", fontsize=12)

plt.xlabel("생존여부")
plt.ylabel("생존자수")

plt.show()
# Out:
# <BarContainer object of 1365 artists>
# Text(0.5, 1.0, 'CryoSleep')
# Text(0.5, 0, '생존여부')
# Text(0, 0.5, '생존자수')
