# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('C:/ds_work/source_code/Project_DS/data/train_update.csv')
df
# Out:
#      PassengerId  HomePlanet  CryoSleep  Cabin  Cabin_num  Cabin_port  \
# 0        0001_01           1          0      1          0           0
# 1        0002_01           0          0      5          0           1
# 2        0003_01           1          0      0          0           1
# 3        0003_02           1          0      0          0           1
# 4        0004_01           0          0      5          1           1
# ...          ...         ...        ...    ...        ...         ...
# 8688     8772_02           1          0      3         90           0
# 8689     3821_01           0          0      4        309           0
# 8690     7746_01           1          1      4        289           0
# 8691     4167_01           0          0      4        309           0
# 8692     2970_01           0          0      5         42           0
#
#       Destination  Age  VIP  RoomService  FoodCourt  ShoppingMall   Spa  \
# ...

# %%
df['VIP'].corr(df['RoomService'],method = 'pearson')
# Out:
# 0.055194045894042365

# %%
df['VIP'].corr(df['ShoppingMall'],method = 'pearson')
# Out:
# 0.019787749006620788

# %%
df['VIP'].corr(df['Spa'],method = 'pearson')
# Out:
# 0.05435316949821644

# %%
df['VIP'].corr(df['VRDeck'],method = 'pearson')
# Out:
# 0.12078229176290654

# %%
df01 = pd.read_csv('C:/ds_work/source_code/Project_DS/data/train.csv')
df01
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df.hist(figsize = (20,20))
plt.show()
# Out:
# array([[<AxesSubplot:title={'center':'HomePlanet'}>,
#         <AxesSubplot:title={'center':'CryoSleep'}>,
#         <AxesSubplot:title={'center':'Cabin'}>,
#         <AxesSubplot:title={'center':'Cabin_num'}>],
#        [<AxesSubplot:title={'center':'Cabin_port'}>,
#         <AxesSubplot:title={'center':'Destination'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'VIP'}>],
#        [<AxesSubplot:title={'center':'RoomService'}>,
#         <AxesSubplot:title={'center':'FoodCourt'}>,
#         <AxesSubplot:title={'center':'ShoppingMall'}>,
#         <AxesSubplot:title={'center':'Spa'}>],
#        [<AxesSubplot:title={'center':'VRDeck'}>,
#         <AxesSubplot:title={'center':'Transported'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)
